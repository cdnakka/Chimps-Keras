# %%
import os
import numpy as np
import librosa
import scipy
import math
import pickle

# %%
#Convert to pcm16
def convert_urban_pcm24_to_pcm16():
    """Convert urbansound codec from PCM_24 to PCM_16."""
    src_dir = ['D:/Thesis/UrbanSound8K/audio/fold{:d}'.format(i+1) for i in range(10)]
    dst_dir = ['D:/Thesis/UrbanSound8K-16bit/audio/fold{:d}'.format(i+1) for i in range(10)]
    converted_wav_paths = []
    for dsrc, ddst in zip(src_dir, dst_dir):
        create_directory(ddst)
        wav_files = filter(lambda FP: FP if FP.endswith('.wav') else None, 
                           [FP for FP in os.listdir(dsrc)])
        for wav_file in wav_files:
            src_wav, dst_wav = os.path.join(dsrc, wav_file), os.path.join(ddst, wav_file)
            convert_wav(src_wav, dst_wav, subtype='PCM_16')
            converted_wav_paths.append(dst_wav)
            print('converted count:', len(converted_wav_paths))
    print(converted_wav_paths, len(converted_wav_paths))


def arange_urban_sound_file_by_class():
    """Arange urbansound files by their classes."""
    src_paths = ["D:/Thesis/UrbanSound8K/audio/fold{:d}".format(i+1) for i in range(10)]
    dst_dir = 'D:/Thesis/UrbanSound8K-16bit/audio-classified'
    CLASSES = [
        'air conditioner',
        'car horn',
        'children playing',
        'dog bark',
        'drilling',
        'engine idling',
        'gun shot',
        'jackhammer',
        'siren',
        'street music']
    CLASSES_STRIPED = [c.replace(' ', '_') for c in CLASSES]
    for src in src_paths:
        fold_dir = glob.glob(os.path.join(src, "*.wav"))
        for fn in fold_dir:
            lbl = int(fn.split('\\')[1].split('-')[1])
            dst = '{dir}/{label}'.format(dir=dst_dir, label=CLASSES_STRIPED[lbl])
            create_directory(dst)
            copy_file(fn, '{dst}/{name}'.format(dst=dst, name=fn.split('\\')[-1]))

# %%
convert_urban_pcm24_to_pcm16()
arange_urban_sound_file_by_class()

# %%
#Sort folders and convert to 16 bit pcm
#Add chimp sounds in folder labelled chimp
#Add Bg sounds
DATASET_16BIT_PATH = "D:/Thesis/UrbanSound8K-16bit/audio-classified"
#DATASET_16BIT_PATH = "D:/Thesis/Keras/Attempt5/subset"

# %%
def getListOfFiles(dirpath):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirpath)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirpath, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)        
    
    return allFiles

def urban_labels(Y, fpaths):
    """urban sound dataset labels."""
    urban_label = lambda path: int(os.path.split(path)[-1].split('-')[1])
    for p in fpaths:
        Y = np.append(Y, [urban_label(p)])
    return Y

def load_sound_files(file_paths):

    X,sr = librosa.load(file_paths, sr=11025, res_type='kaiser_fast')
    mfccs=np.mean(librosa.feature.mfcc(y=X,sr=sr,n_mfcc=40).T,axis=0)

    return mfccs

# %%
filepaths = np.asarray(getListOfFiles(DATASET_16BIT_PATH))
print("No of entries in our Dataset: ", filepaths.shape)

Y = np.ndarray(0)
labels = urban_labels(Y, filepaths)
print("Labels : ",labels.shape)

with open("filepaths.txt", "wb") as fp:   #Pickling
    pickle.dump(filepaths, fp)
    
with open("labels.txt", "wb") as fp:   #Pickling
    pickle.dump(labels, fp)
# Out:
# No of entries in our Dataset:  (11708,)
# Labels :  (11708,)

# %%
raw = []
for i in range(len(filepaths)):
    #len(filepaths) when ready
    raw.append(load_sound_files(filepaths[i]))
    if i%100 == 0 :
        print("Raw Sound loaded for :", filepaths[i])

#np.save("Attempt5/raw",np.asarray(raw))
#del raw
# Out:
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\100852-0-0-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\13230-0-0-22.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\146714-0-0-41.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\162103-0-0-14.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\177726-0-0-15.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\178686-0-0-43.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\189982-0-0-20.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\204240-0-0-23.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\57320-0-0-5.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\air_conditioner\74677-0-0-21.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0000.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0100.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0200.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0300.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0400.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0500.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0600.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0700.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0800.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_0900.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_1000.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_1100.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_1200.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_1300.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\backgrounds\Background-11-0_1400.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\car_horn\125520-1-4-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\car_horn\179867-1-0-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\car_horn\28808-1-0-7.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\car_horn\72259-1-7-22.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\car_horn\94868-1-2-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\132855-2-0-77.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\155219-2-0-26.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\161005-2-0-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\174786-2-0-39.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\182800-2-1-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\193697-2-0-90.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\206037-2-0-22.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\52882-2-0-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\72015-2-0-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\children_playing\97331-2-0-35.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-0 (178).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-0 (268).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-0 (90).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-1 (180).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-1 (270).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-1 (360).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-1 (450).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-1 (540).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-1 (630).wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-2_007.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-2_107.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-2_207.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-2_307.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-3_073.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\chimp\Chimps-10-3_173.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\116484-3-0-8.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\147672-3-2-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\173994-3-0-44.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\18581-3-1-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\203356-3-0-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\31325-3-4-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\49808-3-1-22.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\65381-3-0-6.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\74723-3-0-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\dog_bark\97193-3-0-4.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\127443-4-0-5.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\147764-4-7-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\167701-4-9-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\180126-4-4-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\185801-4-0-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\34643-4-2-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\55020-4-0-12.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\66623-4-0-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\76086-4-0-29.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\drilling\99192-4-0-52.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\106015-5-0-3.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\113203-5-3-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\144007-5-0-5.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\154758-5-0-20.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\17578-5-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\18592-5-0-3.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\201988-5-0-22.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\39856-5-0-14.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\62567-5-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\engine_idling\94710-5-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\gun_shot\145206-6-2-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\gun_shot\159710-6-0-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\gun_shot\197320-6-9-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\103074-7-4-6.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\105029-7-3-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\14772-7-2-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\165039-7-12-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\177537-7-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\180937-7-1-15.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\188823-7-2-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\22883-7-19-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\31884-7-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\jackhammer\62837-7-1-73.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\102871-8-0-7.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\118279-8-0-4.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\156869-8-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\158608-8-0-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\159748-8-2-0.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\184623-8-0-1.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\24347-8-0-22.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\40717-8-0-2.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\74364-8-1-26.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\siren\94636-8-0-8.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\115418-9-0-12.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\14385-9-0-17.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\155227-9-0-24.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\171406-9-0-90.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\186339-9-0-17.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\26270-9-0-32.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\52411-9-0-6.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\7390-9-1-5.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\89442-9-0-14.wav
# Raw Sound loaded for : D:/Thesis/UrbanSound8K-16bit/audio-classified\street_music\99180-9-0-49.wav
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2ddf63a7d368> in <module>()
#       6         print("Raw Sound loaded for :", filepaths[i])
#       7
# ----> 8 np.save("Attempt5/raw",np.asarray(raw))
#       9 #del raw
#
# d:\python36\lib\site-packages\numpy\lib\npyio.py in save(file, arr, allow_pickle, fix_imports)
#     490         if not file.endswith('.npy'):
#     491             file = file + '.npy'
# --> 492         fid = open(file, "wb")
#     493         own_fid = True
#     494     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Attempt5/raw.npy'

# %%
np.save("Attempt5-NN/raw",np.asarray(raw))
#del raw
raw = np.load("Attempt5-NN/raw.npy")

# %%
from sklearn.model_selection import train_test_split
XTrain,XTest,YTrain,YTest=train_test_split(raw,labels,test_size=0.2)

from keras.utils import to_categorical

YTrain = to_categorical(YTrain, num_classes=12)
YTest = to_categorical(YTest, num_classes=12)

del raw

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D, GlobalAveragePooling2D
from keras import optimizers
from keras.utils import np_utils
from sklearn import metrics

# %%
# copied 
try_model = Sequential()

try_model.add(Dense(256, input_shape=(40,)))
try_model.add(Activation('relu'))
try_model.add(Dropout(0.5))

try_model.add(Dense(256))
try_model.add(Activation('relu'))
try_model.add(Dropout(0.5))

# try_model.add(Dense(256))
# try_model.add(Activation('relu'))
# try_model.add(Dropout(0.5))

try_model.add(Dense(256))
try_model.add(Activation('relu'))
try_model.add(Dropout(0.5))

try_model.add(Dense(12))
try_model.add(Activation('softmax'))

try_model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
try_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               10496
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_6 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_7 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 12)                3084
# _________________________________________________________________
# activation_8 (Activation)    (None, 12)                0
# =================================================================
# Total params: 145,164
# Trainable params: 145,164
# Non-trainable params: 0
# _________________________________________________________________

# %%
try_model.fit(np.array(XTrain), np.array(YTrain), batch_size=32, epochs=200, validation_data=(np.array(XTest), np.array(YTest)))
# Out:
# Train on 9366 samples, validate on 2342 samples
# Epoch 1/200
# 9366/9366 [==============================] - 5s 567us/step - loss: 9.8537 - acc: 0.1825 - val_loss: 2.1264 - val_acc: 0.3433
# Epoch 2/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 2.3448 - acc: 0.3393 - val_loss: 1.6561 - val_acc: 0.5196
# Epoch 3/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 1.7098 - acc: 0.4403 - val_loss: 1.4036 - val_acc: 0.5769
# Epoch 4/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 1.5010 - acc: 0.5007 - val_loss: 1.2307 - val_acc: 0.6234
# Epoch 5/200
# 9366/9366 [==============================] - 1s 156us/step - loss: 1.3834 - acc: 0.5361 - val_loss: 1.1358 - val_acc: 0.6541
# Epoch 6/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 1.2860 - acc: 0.5715 - val_loss: 1.0453 - val_acc: 0.6815
# Epoch 7/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 1.2139 - acc: 0.5991 - val_loss: 0.9919 - val_acc: 0.6951
# Epoch 8/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 1.1514 - acc: 0.6215 - val_loss: 0.9461 - val_acc: 0.7088
# Epoch 9/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 1.1184 - acc: 0.6309 - val_loss: 0.9294 - val_acc: 0.7361
# Epoch 10/200
# 9366/9366 [==============================] - 2s 164us/step - loss: 1.0381 - acc: 0.6531 - val_loss: 0.8710 - val_acc: 0.7353
# Epoch 11/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 1.0442 - acc: 0.6551 - val_loss: 0.8491 - val_acc: 0.7323
# Epoch 12/200
# 9366/9366 [==============================] - 2s 202us/step - loss: 1.0085 - acc: 0.6762 - val_loss: 0.8169 - val_acc: 0.7464
# Epoch 13/200
# 9366/9366 [==============================] - 2s 188us/step - loss: 0.9760 - acc: 0.6761 - val_loss: 0.7805 - val_acc: 0.7523
# Epoch 14/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.9571 - acc: 0.6817 - val_loss: 0.7510 - val_acc: 0.7652
# Epoch 15/200
# 9366/9366 [==============================] - 2s 181us/step - loss: 0.9479 - acc: 0.6882 - val_loss: 0.7623 - val_acc: 0.7519
# Epoch 16/200
# 9366/9366 [==============================] - 2s 164us/step - loss: 0.9111 - acc: 0.6993 - val_loss: 0.7330 - val_acc: 0.7724
# Epoch 17/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.8918 - acc: 0.7059 - val_loss: 0.7037 - val_acc: 0.7669
# Epoch 18/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.8931 - acc: 0.7103 - val_loss: 0.6903 - val_acc: 0.7801
# Epoch 19/200
# 9366/9366 [==============================] - 2s 189us/step - loss: 0.8582 - acc: 0.7249 - val_loss: 0.6513 - val_acc: 0.7891
# Epoch 20/200
# 9366/9366 [==============================] - 2s 175us/step - loss: 0.8510 - acc: 0.7228 - val_loss: 0.6532 - val_acc: 0.7925
# Epoch 21/200
# 9366/9366 [==============================] - 1s 155us/step - loss: 0.8434 - acc: 0.7243 - val_loss: 0.6519 - val_acc: 0.7857
# Epoch 22/200
# 9366/9366 [==============================] - 1s 158us/step - loss: 0.8355 - acc: 0.7250 - val_loss: 0.6538 - val_acc: 0.7861
# Epoch 23/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.8229 - acc: 0.7305 - val_loss: 0.6523 - val_acc: 0.7955
# Epoch 24/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.8088 - acc: 0.7355 - val_loss: 0.6185 - val_acc: 0.8010
# Epoch 25/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.7947 - acc: 0.7419 - val_loss: 0.5962 - val_acc: 0.8087
# Epoch 26/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.7843 - acc: 0.7491 - val_loss: 0.6141 - val_acc: 0.8015
# Epoch 27/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.7885 - acc: 0.7457 - val_loss: 0.6295 - val_acc: 0.7976
# Epoch 28/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.7819 - acc: 0.7460 - val_loss: 0.5758 - val_acc: 0.8108
# Epoch 29/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.7663 - acc: 0.7493 - val_loss: 0.6011 - val_acc: 0.8143
# Epoch 30/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.7806 - acc: 0.7428 - val_loss: 0.5810 - val_acc: 0.8143
# Epoch 31/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.7527 - acc: 0.7589 - val_loss: 0.5809 - val_acc: 0.8130
# Epoch 32/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.7483 - acc: 0.7570 - val_loss: 0.5673 - val_acc: 0.8190
# Epoch 33/200
# 9366/9366 [==============================] - 1s 155us/step - loss: 0.7271 - acc: 0.7609 - val_loss: 0.5493 - val_acc: 0.8241
# Epoch 34/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.7462 - acc: 0.7557 - val_loss: 0.5527 - val_acc: 0.8194
# Epoch 35/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.7288 - acc: 0.7601 - val_loss: 0.5701 - val_acc: 0.8113
# Epoch 36/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.7101 - acc: 0.7697 - val_loss: 0.5433 - val_acc: 0.8215
# Epoch 37/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.7157 - acc: 0.7667 - val_loss: 0.5604 - val_acc: 0.8262
# Epoch 38/200
# 9366/9366 [==============================] - 1s 153us/step - loss: 0.7125 - acc: 0.7667 - val_loss: 0.5346 - val_acc: 0.8335
# Epoch 39/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.7187 - acc: 0.7673 - val_loss: 0.5376 - val_acc: 0.8326
# Epoch 40/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.7030 - acc: 0.7698 - val_loss: 0.5472 - val_acc: 0.8275
# Epoch 41/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6877 - acc: 0.7735 - val_loss: 0.5424 - val_acc: 0.8228
# Epoch 42/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.7021 - acc: 0.7735 - val_loss: 0.5429 - val_acc: 0.8301
# Epoch 43/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.7013 - acc: 0.7748 - val_loss: 0.5377 - val_acc: 0.8249
# Epoch 44/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.7011 - acc: 0.7766 - val_loss: 0.5317 - val_acc: 0.8279
# Epoch 45/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6968 - acc: 0.7714 - val_loss: 0.5374 - val_acc: 0.8343
# Epoch 46/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6791 - acc: 0.7764 - val_loss: 0.5204 - val_acc: 0.8284
# Epoch 47/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6729 - acc: 0.7823 - val_loss: 0.5283 - val_acc: 0.8424
# Epoch 48/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6815 - acc: 0.7776 - val_loss: 0.5059 - val_acc: 0.8313
# Epoch 49/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.6574 - acc: 0.7834 - val_loss: 0.5114 - val_acc: 0.8403
# Epoch 50/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6671 - acc: 0.7855 - val_loss: 0.5082 - val_acc: 0.8339
# Epoch 51/200
# 9366/9366 [==============================] - 2s 168us/step - loss: 0.6577 - acc: 0.7937 - val_loss: 0.5041 - val_acc: 0.8313
# Epoch 52/200
# 9366/9366 [==============================] - 2s 163us/step - loss: 0.6712 - acc: 0.7824 - val_loss: 0.5144 - val_acc: 0.8390
# Epoch 53/200
# 9366/9366 [==============================] - 2s 178us/step - loss: 0.6638 - acc: 0.7871 - val_loss: 0.5215 - val_acc: 0.8360
# Epoch 54/200
# 9366/9366 [==============================] - 2s 185us/step - loss: 0.6708 - acc: 0.7870 - val_loss: 0.4919 - val_acc: 0.8510
# Epoch 55/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.6520 - acc: 0.7900 - val_loss: 0.5008 - val_acc: 0.8450
# Epoch 56/200
# 9366/9366 [==============================] - 1s 155us/step - loss: 0.6599 - acc: 0.7898 - val_loss: 0.5126 - val_acc: 0.8403
# Epoch 57/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.6693 - acc: 0.7818 - val_loss: 0.5141 - val_acc: 0.8382
# Epoch 58/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6654 - acc: 0.7835 - val_loss: 0.4916 - val_acc: 0.8454
# Epoch 59/200
# 9366/9366 [==============================] - 2s 182us/step - loss: 0.6515 - acc: 0.7917 - val_loss: 0.4914 - val_acc: 0.8446
# Epoch 60/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6421 - acc: 0.7952 - val_loss: 0.4960 - val_acc: 0.8412
# Epoch 61/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.6504 - acc: 0.7963 - val_loss: 0.4912 - val_acc: 0.8471
# Epoch 62/200
# 9366/9366 [==============================] - 2s 177us/step - loss: 0.6469 - acc: 0.7961 - val_loss: 0.5217 - val_acc: 0.8416
# Epoch 63/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6436 - acc: 0.7937 - val_loss: 0.4916 - val_acc: 0.8454
# Epoch 64/200
# 9366/9366 [==============================] - 1s 147us/step - loss: 0.6257 - acc: 0.7993 - val_loss: 0.4602 - val_acc: 0.8484
# Epoch 65/200
# 9366/9366 [==============================] - 1s 147us/step - loss: 0.6436 - acc: 0.7960 - val_loss: 0.4966 - val_acc: 0.8450
# Epoch 66/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6508 - acc: 0.7891 - val_loss: 0.4859 - val_acc: 0.8412
# Epoch 67/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6283 - acc: 0.7992 - val_loss: 0.4690 - val_acc: 0.8450
# Epoch 68/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6158 - acc: 0.8038 - val_loss: 0.4856 - val_acc: 0.8488
# Epoch 69/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.6284 - acc: 0.7965 - val_loss: 0.4767 - val_acc: 0.8523
# Epoch 70/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6292 - acc: 0.7969 - val_loss: 0.4653 - val_acc: 0.8544
# Epoch 71/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6331 - acc: 0.7950 - val_loss: 0.4531 - val_acc: 0.8582
# Epoch 72/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6127 - acc: 0.8031 - val_loss: 0.4637 - val_acc: 0.8578
# Epoch 73/200
# 9366/9366 [==============================] - 1s 149us/step - loss: 0.6207 - acc: 0.8019 - val_loss: 0.4909 - val_acc: 0.8403
# Epoch 74/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6389 - acc: 0.7976 - val_loss: 0.4707 - val_acc: 0.8535
# Epoch 75/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6444 - acc: 0.7920 - val_loss: 0.4854 - val_acc: 0.8493
# Epoch 76/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.6336 - acc: 0.7955 - val_loss: 0.4818 - val_acc: 0.8446
# Epoch 77/200
# 9366/9366 [==============================] - 1s 147us/step - loss: 0.6196 - acc: 0.8022 - val_loss: 0.4858 - val_acc: 0.8420
# Epoch 78/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.6354 - acc: 0.7972 - val_loss: 0.4684 - val_acc: 0.8612
# Epoch 79/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.6084 - acc: 0.8100 - val_loss: 0.4669 - val_acc: 0.8574
# Epoch 80/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6238 - acc: 0.8029 - val_loss: 0.4707 - val_acc: 0.8531
# Epoch 81/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.5953 - acc: 0.8075 - val_loss: 0.4693 - val_acc: 0.8476
# Epoch 82/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6023 - acc: 0.8101 - val_loss: 0.4790 - val_acc: 0.8454
# Epoch 83/200
# 9366/9366 [==============================] - 1s 147us/step - loss: 0.6251 - acc: 0.8031 - val_loss: 0.4498 - val_acc: 0.8574
# Epoch 84/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.6024 - acc: 0.8038 - val_loss: 0.4534 - val_acc: 0.8544
# Epoch 85/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6028 - acc: 0.8057 - val_loss: 0.4757 - val_acc: 0.8471
# Epoch 86/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.6133 - acc: 0.8080 - val_loss: 0.4606 - val_acc: 0.8540
# Epoch 87/200
# 9366/9366 [==============================] - 1s 159us/step - loss: 0.6014 - acc: 0.8073 - val_loss: 0.4691 - val_acc: 0.8557
# Epoch 88/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.6120 - acc: 0.8041 - val_loss: 0.4618 - val_acc: 0.8454
# Epoch 89/200
# 9366/9366 [==============================] - 2s 176us/step - loss: 0.6117 - acc: 0.8085 - val_loss: 0.4461 - val_acc: 0.8565
# Epoch 90/200
# 9366/9366 [==============================] - 1s 160us/step - loss: 0.6000 - acc: 0.8108 - val_loss: 0.4504 - val_acc: 0.8574
# Epoch 91/200
# 9366/9366 [==============================] - 1s 153us/step - loss: 0.5828 - acc: 0.8093 - val_loss: 0.4424 - val_acc: 0.8612
# Epoch 92/200
# 9366/9366 [==============================] - 2s 176us/step - loss: 0.5937 - acc: 0.8123 - val_loss: 0.4593 - val_acc: 0.8574
# Epoch 93/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.6050 - acc: 0.8104 - val_loss: 0.4629 - val_acc: 0.8488
# Epoch 94/200
# 9366/9366 [==============================] - 2s 167us/step - loss: 0.6039 - acc: 0.8076 - val_loss: 0.4658 - val_acc: 0.8535
# Epoch 95/200
# 9366/9366 [==============================] - 1s 160us/step - loss: 0.6061 - acc: 0.8076 - val_loss: 0.4441 - val_acc: 0.8642
# Epoch 96/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.5954 - acc: 0.8095 - val_loss: 0.4350 - val_acc: 0.8617
# Epoch 97/200
# 9366/9366 [==============================] - 2s 162us/step - loss: 0.5841 - acc: 0.8160 - val_loss: 0.4472 - val_acc: 0.8608
# Epoch 98/200
# 9366/9366 [==============================] - 1s 158us/step - loss: 0.6036 - acc: 0.8092 - val_loss: 0.4623 - val_acc: 0.8557
# Epoch 99/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5924 - acc: 0.8128 - val_loss: 0.4561 - val_acc: 0.8553
# Epoch 100/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.6064 - acc: 0.8128 - val_loss: 0.4392 - val_acc: 0.8608
# Epoch 101/200
# 9366/9366 [==============================] - 1s 153us/step - loss: 0.5807 - acc: 0.8168 - val_loss: 0.4562 - val_acc: 0.8506
# Epoch 102/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6082 - acc: 0.8086 - val_loss: 0.4518 - val_acc: 0.8553
# Epoch 103/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.6076 - acc: 0.8062 - val_loss: 0.4663 - val_acc: 0.8591
# Epoch 104/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5938 - acc: 0.8125 - val_loss: 0.4489 - val_acc: 0.8553
# Epoch 105/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5922 - acc: 0.8087 - val_loss: 0.4488 - val_acc: 0.8595
# Epoch 106/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.5845 - acc: 0.8136 - val_loss: 0.4442 - val_acc: 0.8621
# Epoch 107/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5795 - acc: 0.8151 - val_loss: 0.4391 - val_acc: 0.8689
# Epoch 108/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.6215 - acc: 0.8102 - val_loss: 0.4592 - val_acc: 0.8570
# Epoch 109/200
# 9366/9366 [==============================] - 1s 153us/step - loss: 0.5760 - acc: 0.8203 - val_loss: 0.4559 - val_acc: 0.8493
# Epoch 110/200
# 9366/9366 [==============================] - 1s 155us/step - loss: 0.5777 - acc: 0.8137 - val_loss: 0.4408 - val_acc: 0.8574
# Epoch 111/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5770 - acc: 0.8148 - val_loss: 0.4399 - val_acc: 0.8612
# Epoch 112/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5766 - acc: 0.8179 - val_loss: 0.4420 - val_acc: 0.8629
# Epoch 113/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5881 - acc: 0.8185 - val_loss: 0.4341 - val_acc: 0.8732
# Epoch 114/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5794 - acc: 0.8234 - val_loss: 0.4453 - val_acc: 0.8617
# Epoch 115/200
# 9366/9366 [==============================] - 1s 155us/step - loss: 0.5737 - acc: 0.8193 - val_loss: 0.4461 - val_acc: 0.8693
# Epoch 116/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5699 - acc: 0.8165 - val_loss: 0.4286 - val_acc: 0.8646
# Epoch 117/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5750 - acc: 0.8171 - val_loss: 0.4316 - val_acc: 0.8693
# Epoch 118/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.5934 - acc: 0.8159 - val_loss: 0.4529 - val_acc: 0.8565
# Epoch 119/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5908 - acc: 0.8185 - val_loss: 0.4433 - val_acc: 0.8642
# Epoch 120/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5769 - acc: 0.8199 - val_loss: 0.4524 - val_acc: 0.8599
# Epoch 121/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.5821 - acc: 0.8173 - val_loss: 0.4231 - val_acc: 0.8621
# Epoch 122/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.5801 - acc: 0.8180 - val_loss: 0.4363 - val_acc: 0.8655
# Epoch 123/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.5740 - acc: 0.8184 - val_loss: 0.4384 - val_acc: 0.8561
# Epoch 124/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5813 - acc: 0.8154 - val_loss: 0.4285 - val_acc: 0.8646
# Epoch 125/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5598 - acc: 0.8224 - val_loss: 0.4429 - val_acc: 0.8587
# Epoch 126/200
# 9366/9366 [==============================] - 1s 156us/step - loss: 0.5645 - acc: 0.8260 - val_loss: 0.4437 - val_acc: 0.8659
# Epoch 127/200
# 9366/9366 [==============================] - 2s 170us/step - loss: 0.5558 - acc: 0.8265 - val_loss: 0.4243 - val_acc: 0.8681
# Epoch 128/200
# 9366/9366 [==============================] - 1s 156us/step - loss: 0.5613 - acc: 0.8272 - val_loss: 0.4160 - val_acc: 0.8766
# Epoch 129/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.5757 - acc: 0.8212 - val_loss: 0.4311 - val_acc: 0.8625
# Epoch 130/200
# 9366/9366 [==============================] - 2s 161us/step - loss: 0.5783 - acc: 0.8168 - val_loss: 0.4189 - val_acc: 0.8736
# Epoch 131/200
# 9366/9366 [==============================] - 2s 201us/step - loss: 0.5795 - acc: 0.8223 - val_loss: 0.4547 - val_acc: 0.8565
# Epoch 132/200
# 9366/9366 [==============================] - 2s 215us/step - loss: 0.5533 - acc: 0.8267 - val_loss: 0.4267 - val_acc: 0.8621
# Epoch 133/200
# 9366/9366 [==============================] - 2s 196us/step - loss: 0.5624 - acc: 0.8228 - val_loss: 0.4372 - val_acc: 0.8604
# Epoch 134/200
# 9366/9366 [==============================] - 2s 175us/step - loss: 0.5673 - acc: 0.8199 - val_loss: 0.4312 - val_acc: 0.8668
# Epoch 135/200
# 9366/9366 [==============================] - 1s 157us/step - loss: 0.5804 - acc: 0.8245 - val_loss: 0.4300 - val_acc: 0.8642
# Epoch 136/200
# 9366/9366 [==============================] - 2s 162us/step - loss: 0.5568 - acc: 0.8227 - val_loss: 0.4253 - val_acc: 0.8689
# Epoch 137/200
# 9366/9366 [==============================] - 2s 162us/step - loss: 0.5377 - acc: 0.8307 - val_loss: 0.4251 - val_acc: 0.8685
# Epoch 138/200
# 9366/9366 [==============================] - 2s 161us/step - loss: 0.5628 - acc: 0.8219 - val_loss: 0.4201 - val_acc: 0.8634
# Epoch 139/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5582 - acc: 0.8255 - val_loss: 0.4387 - val_acc: 0.8625
# Epoch 140/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5472 - acc: 0.8326 - val_loss: 0.4243 - val_acc: 0.8685
# Epoch 141/200
# 9366/9366 [==============================] - 1s 159us/step - loss: 0.5742 - acc: 0.8203 - val_loss: 0.4237 - val_acc: 0.8681
# Epoch 142/200
# 9366/9366 [==============================] - 2s 168us/step - loss: 0.5540 - acc: 0.8271 - val_loss: 0.4202 - val_acc: 0.8715
# Epoch 143/200
# 9366/9366 [==============================] - 2s 212us/step - loss: 0.5887 - acc: 0.8156 - val_loss: 0.4363 - val_acc: 0.8676
# Epoch 144/200
# 9366/9366 [==============================] - 2s 209us/step - loss: 0.5404 - acc: 0.8310 - val_loss: 0.4204 - val_acc: 0.8711
# Epoch 145/200
# 9366/9366 [==============================] - 2s 215us/step - loss: 0.5425 - acc: 0.8285 - val_loss: 0.4184 - val_acc: 0.8659
# Epoch 146/200
# 9366/9366 [==============================] - 2s 182us/step - loss: 0.5335 - acc: 0.8312 - val_loss: 0.4144 - val_acc: 0.8698
# Epoch 147/200
# 9366/9366 [==============================] - 2s 165us/step - loss: 0.5511 - acc: 0.8281 - val_loss: 0.4353 - val_acc: 0.8608
# Epoch 148/200
# 9366/9366 [==============================] - 1s 156us/step - loss: 0.5679 - acc: 0.8213 - val_loss: 0.4273 - val_acc: 0.8664
# Epoch 149/200
# 9366/9366 [==============================] - 1s 155us/step - loss: 0.5309 - acc: 0.8339 - val_loss: 0.4158 - val_acc: 0.8685
# Epoch 150/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5736 - acc: 0.8197 - val_loss: 0.4204 - val_acc: 0.8689
# Epoch 151/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.5547 - acc: 0.8259 - val_loss: 0.4144 - val_acc: 0.8723
# Epoch 152/200
# 9366/9366 [==============================] - 1s 154us/step - loss: 0.5390 - acc: 0.8282 - val_loss: 0.4231 - val_acc: 0.8664
# Epoch 153/200
# 9366/9366 [==============================] - 2s 167us/step - loss: 0.5594 - acc: 0.8238 - val_loss: 0.4114 - val_acc: 0.8753
# Epoch 154/200
# 9366/9366 [==============================] - 2s 216us/step - loss: 0.5863 - acc: 0.8191 - val_loss: 0.4360 - val_acc: 0.8617
# Epoch 155/200
# 9366/9366 [==============================] - 2s 202us/step - loss: 0.5461 - acc: 0.8295 - val_loss: 0.4372 - val_acc: 0.8599
# Epoch 156/200
# 9366/9366 [==============================] - 2s 187us/step - loss: 0.5453 - acc: 0.8313 - val_loss: 0.3946 - val_acc: 0.8779
# Epoch 157/200
# 9366/9366 [==============================] - 2s 186us/step - loss: 0.5476 - acc: 0.8247 - val_loss: 0.4139 - val_acc: 0.8711
# Epoch 158/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5791 - acc: 0.8250 - val_loss: 0.4291 - val_acc: 0.8625
# Epoch 159/200
# 9366/9366 [==============================] - 1s 158us/step - loss: 0.5655 - acc: 0.8282 - val_loss: 0.4275 - val_acc: 0.8655
# Epoch 160/200
# 9366/9366 [==============================] - 2s 184us/step - loss: 0.5669 - acc: 0.8264 - val_loss: 0.4222 - val_acc: 0.8655
# Epoch 161/200
# 9366/9366 [==============================] - 2s 177us/step - loss: 0.5540 - acc: 0.8265 - val_loss: 0.4244 - val_acc: 0.8676
# Epoch 162/200
# 9366/9366 [==============================] - 2s 181us/step - loss: 0.5490 - acc: 0.8327 - val_loss: 0.4123 - val_acc: 0.8676
# Epoch 163/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5612 - acc: 0.8252 - val_loss: 0.4169 - val_acc: 0.8775
# Epoch 164/200
# 9366/9366 [==============================] - 2s 204us/step - loss: 0.5363 - acc: 0.8311 - val_loss: 0.4202 - val_acc: 0.8685
# Epoch 165/200
# 9366/9366 [==============================] - 2s 169us/step - loss: 0.5427 - acc: 0.8325 - val_loss: 0.4073 - val_acc: 0.8689
# Epoch 166/200
# 9366/9366 [==============================] - 2s 228us/step - loss: 0.5310 - acc: 0.8327 - val_loss: 0.4030 - val_acc: 0.8740
# Epoch 167/200
# 9366/9366 [==============================] - 2s 189us/step - loss: 0.5543 - acc: 0.8268 - val_loss: 0.4230 - val_acc: 0.8685
# Epoch 168/200
# 9366/9366 [==============================] - 2s 166us/step - loss: 0.5292 - acc: 0.8376 - val_loss: 0.4206 - val_acc: 0.8728
# Epoch 169/200
# 9366/9366 [==============================] - 2s 160us/step - loss: 0.5390 - acc: 0.8278 - val_loss: 0.3963 - val_acc: 0.8749
# Epoch 170/200
# 9366/9366 [==============================] - 2s 172us/step - loss: 0.5371 - acc: 0.8327 - val_loss: 0.4326 - val_acc: 0.8664
# Epoch 171/200
# 9366/9366 [==============================] - 2s 166us/step - loss: 0.5463 - acc: 0.8294 - val_loss: 0.4219 - val_acc: 0.8706
# Epoch 172/200
# 9366/9366 [==============================] - 2s 175us/step - loss: 0.5559 - acc: 0.8284 - val_loss: 0.4291 - val_acc: 0.8711
# Epoch 173/200
# 9366/9366 [==============================] - ETA: 0s - loss: 0.5426 - acc: 0.832 - 1s 156us/step - loss: 0.5404 - acc: 0.8325 - val_loss: 0.4412 - val_acc: 0.8595
# Epoch 174/200
# 9366/9366 [==============================] - 2s 166us/step - loss: 0.5311 - acc: 0.8339 - val_loss: 0.4210 - val_acc: 0.8702
# Epoch 175/200
# 9366/9366 [==============================] - 2s 219us/step - loss: 0.5376 - acc: 0.8345 - val_loss: 0.4091 - val_acc: 0.8676
# Epoch 176/200
# 9366/9366 [==============================] - 2s 181us/step - loss: 0.5417 - acc: 0.8337 - val_loss: 0.4131 - val_acc: 0.8655
# Epoch 177/200
# 9366/9366 [==============================] - 2s 185us/step - loss: 0.5403 - acc: 0.8358 - val_loss: 0.4097 - val_acc: 0.8711
# Epoch 178/200
# 9366/9366 [==============================] - 2s 199us/step - loss: 0.5446 - acc: 0.8328 - val_loss: 0.4132 - val_acc: 0.8681
# Epoch 179/200
# 9366/9366 [==============================] - 2s 222us/step - loss: 0.5516 - acc: 0.8326 - val_loss: 0.4163 - val_acc: 0.8757
# Epoch 180/200
# 9366/9366 [==============================] - 2s 211us/step - loss: 0.5354 - acc: 0.8312 - val_loss: 0.4278 - val_acc: 0.8659
# Epoch 181/200
# 9366/9366 [==============================] - 1s 147us/step - loss: 0.5471 - acc: 0.8346 - val_loss: 0.4238 - val_acc: 0.8698
# Epoch 182/200
# 9366/9366 [==============================] - 1s 146us/step - loss: 0.5355 - acc: 0.8271 - val_loss: 0.4169 - val_acc: 0.8711
# Epoch 183/200
# 9366/9366 [==============================] - 1s 148us/step - loss: 0.5069 - acc: 0.8434 - val_loss: 0.3985 - val_acc: 0.8740
# Epoch 184/200
# 9366/9366 [==============================] - 1s 160us/step - loss: 0.5439 - acc: 0.8327 - val_loss: 0.4069 - val_acc: 0.8638
# Epoch 185/200
# 9366/9366 [==============================] - 1s 147us/step - loss: 0.5590 - acc: 0.8269 - val_loss: 0.4217 - val_acc: 0.8676
# Epoch 186/200
# 9366/9366 [==============================] - 1s 144us/step - loss: 0.5583 - acc: 0.8279 - val_loss: 0.4106 - val_acc: 0.8676
# Epoch 187/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5280 - acc: 0.8334 - val_loss: 0.4076 - val_acc: 0.8732
# Epoch 188/200
# 9366/9366 [==============================] - 1s 159us/step - loss: 0.5675 - acc: 0.8288 - val_loss: 0.4069 - val_acc: 0.8723
# Epoch 189/200
# 9366/9366 [==============================] - 2s 164us/step - loss: 0.5352 - acc: 0.8355 - val_loss: 0.4069 - val_acc: 0.8728
# Epoch 190/200
# 9366/9366 [==============================] - 2s 164us/step - loss: 0.5506 - acc: 0.8396 - val_loss: 0.4052 - val_acc: 0.8740
# Epoch 191/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5265 - acc: 0.8342 - val_loss: 0.4039 - val_acc: 0.8800
# Epoch 192/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.5407 - acc: 0.8287 - val_loss: 0.4179 - val_acc: 0.8711
# Epoch 193/200
# 9366/9366 [==============================] - 2s 163us/step - loss: 0.5363 - acc: 0.8310 - val_loss: 0.4140 - val_acc: 0.8723
# Epoch 194/200
# 9366/9366 [==============================] - 2s 211us/step - loss: 0.5340 - acc: 0.8356 - val_loss: 0.4148 - val_acc: 0.8715
# Epoch 195/200
# 9366/9366 [==============================] - 2s 171us/step - loss: 0.5266 - acc: 0.8392 - val_loss: 0.4177 - val_acc: 0.8736
# Epoch 196/200
# 9366/9366 [==============================] - 1s 151us/step - loss: 0.5468 - acc: 0.8322 - val_loss: 0.4296 - val_acc: 0.8664
# Epoch 197/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5456 - acc: 0.8350 - val_loss: 0.3962 - val_acc: 0.8800
# Epoch 198/200
# 9366/9366 [==============================] - 1s 152us/step - loss: 0.5227 - acc: 0.8389 - val_loss: 0.4156 - val_acc: 0.8715
# Epoch 199/200
# 9366/9366 [==============================] - 1s 150us/step - loss: 0.5380 - acc: 0.8385 - val_loss: 0.4138 - val_acc: 0.8728
# Epoch 200/200
# 9366/9366 [==============================] - 2s 162us/step - loss: 0.5300 - acc: 0.8331 - val_loss: 0.3930 - val_acc: 0.8787

# %%
#On training Set
train_evaluate = try_model.evaluate(x=np.array(XTrain), y=np.array(YTrain), batch_size=32)
print(train_evaluate)
#On test Set
test_evaluate = try_model.evaluate(x=np.array(XTest), y=np.array(YTest), batch_size=32)
print(test_evaluate)
# Out:
# 9366/9366 [==============================] - 1s 63us/step
# [0.2650230877831683, 0.9221652786675208]
# 2342/2342 [==============================] - 0s 93us/step
# [0.39296177146681144, 0.8787361229209183]

# %%
#voila

# %%
from sklearn.metrics import classification_report
import numpy as np

#Test Set Metrics
Y_test = np.argmax(YTest, axis=1) # Convert one-hot to index
y_pred = try_model.predict_classes(XTest)
print(classification_report(Y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.80      0.89      0.84       206
#           1       0.99      0.86      0.92        99
#           2       0.61      0.79      0.69       189
#           3       0.84      0.68      0.75       191
#           4       0.90      0.85      0.88       188
#           5       0.95      0.92      0.93       200
#           6       0.97      0.66      0.79        92
#           7       0.88      0.98      0.93       213
#           8       0.94      0.91      0.93       171
#           9       0.76      0.75      0.76       199
#          10       0.99      0.99      0.99       289
#          11       0.99      1.00      1.00       305
#
# avg / total       0.89      0.88      0.88      2342

# %%
#Train Set Metrics
Y_train = np.argmax(YTrain, axis=1) # Convert one-hot to index
y_pred = try_model.predict_classes(XTrain)
print(classification_report(Y_train, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.94      0.89       794
#           1       1.00      0.95      0.97       330
#           2       0.69      0.85      0.76       811
#           3       0.95      0.80      0.87       809
#           4       0.95      0.90      0.93       812
#           5       0.99      0.95      0.97       800
#           6       0.97      0.71      0.82       282
#           7       0.89      0.99      0.94       787
#           8       0.96      0.96      0.96       758
#           9       0.89      0.82      0.86       801
#          10       1.00      1.00      1.00      1203
#          11       1.00      1.00      1.00      1179
#
# avg / total       0.93      0.92      0.92      9366

# %%
#testing on other samples
import IPython.display as ipd

inf = []
inf.append(load_sound_files('Attempt5-NN/Chimp_inference.wav'))
ipd.display(ipd.Audio('Attempt5-NN/Chimp_inference.wav'))

# inf.append(load_sound_files('Attempt5/Chimp_inference2.wav'))
# ipd.display(ipd.Audio('Attempt5/Chimp_inference2.wav'))

# inf.append(load_sound_files('Attempt5/Chimp_inference3.wav'))
# ipd.display(ipd.Audio('Attempt5/Chimp_inference3.wav'))

inf.append(load_sound_files('Attempt5-NN/Chimpanzee_Sound_Effect_1.wav'))
ipd.display(ipd.Audio('Attempt5-NN/Chimpanzee_Sound_Effect_1.wav'))

inf.append(load_sound_files('Attempt5-NN/Chimpanzee_Sound_Effect_2.wav'))
ipd.display(ipd.Audio('Attempt5-NN/Chimpanzee_Sound_Effect_2.wav'))

# inf.append(load_sound_files('Attempt5/Chimpanzee_Sound_Effect_3.wav'))
# ipd.display(ipd.Audio('Attempt5/Chimpanzee_Sound_Effect_3.wav'))

inf.append(load_sound_files('Attempt5-NN/Chimpanzee_Sound_Effect_4.wav'))
ipd.display(ipd.Audio('Attempt5-NN/Chimpanzee_Sound_Effect_4.wav'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
inf_pred = try_model.predict_classes(np.array(inf))
print(inf_pred)
# Out:
# [10 10  3 10]

# %% [markdown]
# ### Conclusion
#   100% precision recall metrics for the chimp calls raises questions regarding overfitting. <br>
#   The model has overfit and does not generalize well for other input formats which have chimp calls.<br>
#   In the above example, the model has predicted some chimp calls(10) as dog_barks(3).
#   Solution : Gotta standardize the dataset a bit more. <br>
#   Added a few files with different sample rates : Same effect of overfitting <br>
#   Working : Appended chimp files with 334 low bitrate files, 174 youtube files of 4 secs length

# %%
inf_pred = try_model.predict(np.array(inf))
inf_pred
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.3622347e-25, 5.9886154e-29,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         7.8717925e-30, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00],
#        [2.6856870e-12, 2.4414741e-11, 7.9392940e-03, 6.4363959e-04,
#         6.4986314e-09, 1.3281738e-11, 1.3543891e-07, 6.4560377e-19,
#         4.0771301e-06, 9.0443208e-09, 9.9141288e-01, 7.7706753e-18],
#        [2.5656612e-03, 1.4101674e-03, 1.9903398e-01, 3.5718465e-01,
#         4.6280599e-03, 8.6301500e-03, 8.1848070e-02, 1.0121330e-05,
#         1.7681420e-01, 5.0936669e-02, 1.1629251e-01, 6.4575009e-04],
#        [2.5963948e-14, 1.9519315e-13, 2.1272654e-05, 9.2184364e-06,
#         1.4755312e-11, 1.6721545e-12, 6.5447653e-10, 3.7647406e-22,
#         1.1074900e-06, 2.9868255e-10, 9.9996841e-01, 5.3742082e-18]],
#       dtype=float32)

# %% [markdown]
# 0 = air_conditioner
# 1 = car_horn
# 2 = children_playing
# 3 = dog_bark
# 4 = drilling
# 5 = engine_idling
# 6 = gun_shot
# 7 = jackhammer
# 8 = siren
# 9 = street_music
# 10 = chimp
# 11 = background

# %%
#Raspberry pi
